# %%
import matplotlib.pyplot as pl
import random
import numpy as np

# %%
lst1 = [random.choice(list(range(20,301))) for i in range(4)]
#pl.axis('on')
pl.pie(lst1, labels=lst1, colors=['#8032CD', '#EE114C', '#38BBC7', '#0CF3B9'], autopct='%06.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1fe9dcd3f70>,
# ...
#  [Text(0.6630911903866582, 0.8776731015768939, '247'),
#   Text(-0.9705978243080704, 0.5176290790213012, '215'),
#   Text(-0.7481899378489497, -0.8063571273955387, '136'),
#   Text(0.6793868485083199, -0.8651205176586285, '242')],
#  [Text(0.36168610384726807, 0.4787307826783057, '029.40%'),
#   Text(-0.5294169950771292, 0.2823431340116188, '025.60%'),
#   Text(-0.4081036024630635, -0.4398311603975665, '016.19%'),
#   Text(0.3705746446409017, -0.4718839187228882, '028.81%')])
